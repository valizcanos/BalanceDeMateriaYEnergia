# %% [markdown]
# # <u> 1. Manual de "markdown" para la escritura de textos científicos en Python </u> <br>

# %% [markdown]
# Markdown es un lenguaje de marcado ligero y popular que es un estándar de escritura para analistas y científicos de datos. A menudo, el procesador Markdown lo convierte en el HTML correspondiente, lo que permite compartirlo fácilmente entre diferentes dispositivos y personas.

# %% [markdown]
# El lenguaje de marcado es similar al lenguaje de marcado de hipertexto (HTML) hecho de etiquetas de marcado, y consiste en la etiqueta de apertura  y la etiqueta de cierre .

# %% [markdown]
# A continuación veremos cómo formatear celdas Markdown en Jupyter:

# %% [markdown]
# ## 1.1. Encabezados

# %% [markdown]
# Los encabezados representan los títulos y subtítulos que desamos mostrar en una sección del documento. Para crear encabezados puede emplear el signo de número (#) seguido de un espacio en blanco para los títulos de las celdas y los encabezados de las secciones. También puede emplear las etiquetas de HTML `<h1><\h1>`, `<h2><\h2>`, `<h3><\h3>`, ..., `<h6><\h6>`. Ejemplo:

# %% [markdown]
# Encabezados con `#`: <br>
# # Balance de materia y energía (con `#`)
# ## Balance de materia y energía (con `##`)
# ### Balance de materia y energía (con `##`)
# ####  Balance de materia y energía (con `####`)

# %% [markdown]
# Encabezados con `<h1></h1>, <h2></h2>, <h3></h3> y <h4></h4>` <br>
# <h1> Balance de materia y energía </h1>
# <h2> Balance de materia y energía </h2>
# <h3> Balance de materia y energía </h3>
# <h4> Balance de materia y energía </h4>

# %% [markdown]
# ## 1.2. Letra negrilla y cursiva

# %% [markdown]
# Para hacer énfasis en alguna palabra podemos emplear la <b>negrilla</b> y <i>cursiva</i>. Para escribir la negrilla podemos emplear el doble **asterístico** (`** palabra **`) para apertura y cierre de la palabra a marcar o la <b>etiqueta</b> `<b>` de HTML (`<b>palabra</b>`). <br>
#
# Para escribir la cursiva podemos emplear el *asterístico* (`* palabra *`) para apertura y cierre de la palabra a marcar o la <i>etiqueta</i> `<i>` de HTML (`<i>palabra</i>`).

# %% [markdown]
# ## 1.3. Fuente minivan

# %% [markdown]
# Rodee el texto con un acento grave (\`), también llamado comilla simple posterior, por ejemplo:

# %% [markdown]
# `Balance de materia y energía`

# %% [markdown]
# ## 1.4. Saltos de línea

# %% [markdown]
# Para crear saltos de linea entre párrafos podemos usa el simbolo `>` seguido de un espacio o la etiqueta de HTML `<br>`. Ejemplo:

# %% [markdown]
# `> Los métodos numéricos son una sucesión de operaciones matemáticas utilizadas para encontrar una solución numérica aproximada a un problema determinado. Es decir, se trata de una serie de cálculos para acercarnos lo más posible a una solución numérica con una precisión razonablemente buena.`
#
# `> Los métodos numéricos son utilizados en ingeniería para facilitar la resolución de problemas que conllevan una enorme cantidad de cálculos, lo que permite ahorrar tiempo.`

# %% [markdown]
# > Los métodos numéricos son una sucesión de operaciones matemáticas utilizadas para encontrar una solución numérica aproximada a un problema determinado. Es decir, se trata de una serie de cálculos para acercarnos lo más posible a una solución numérica con una precisión razonablemente buena.
#
# > Los métodos numéricos son utilizados en ingeniería para facilitar la resolución de problemas que conllevan una enorme cantidad de cálculos, lo que permite ahorrar tiempo.

# %% [markdown]
# `Los métodos numéricos son una sucesión de operaciones matemáticas utilizadas para encontrar una solución numérica aproximada a un problema determinado. Es decir, se trata de una serie de cálculos para acercarnos lo más posible a una solución numérica con una precisión razonablemente buena. <br>`
#
# `Los métodos numéricos son utilizados en ingeniería para facilitar la resolución de problemas que conllevan una enorme cantidad de cálculos, lo que permite ahorrar tiempo. <br>`

# %% [markdown]
# Los métodos numéricos son una sucesión de operaciones matemáticas utilizadas para encontrar una solución numérica aproximada a un problema determinado. Es decir, se trata de una serie de cálculos para acercarnos lo más posible a una solución numérica con una precisión razonablemente buena. <br>
#
# Los métodos numéricos son utilizados en ingeniería para facilitar la resolución de problemas que conllevan una enorme cantidad de cálculos, lo que permite ahorrar tiempo. <br>

# %% [markdown]
# ## 1.5. Ingresar hipervínculos

# %% [markdown]
# Para ingresar links de alguna página web podemos emplear dos guiones bajos de apertura y cierre (`__[texto](http://url)__`) o la etíqueta de HTML `<a>` (`<a href="http://url_">texto</a>`). Por ejemplo:

# %% [markdown]
# `<a href="https://www.markdownguide.org/basic-syntax/">Bases de Markdown </a>` <br>
# <a href="https://www.markdownguide.org/basic-syntax/">Bases de Markdown </a>

# %% [markdown]
# `__Guía avanzada https://www.markdownguide.org/extended-syntax/__` <br>
# __Guía avanzada https://www.markdownguide.org/extended-syntax/__

# %% [markdown]
# ## 1.6. Ingresar viñetas

# %% [markdown]
# Para crear una viñeta circular, use uno de los siguientes métodos. Cada viñeta debe estar en su propia línea. Un guión (`-`), un asterisco (`*`) o un número (`1.`) seguido de uno o dos espacios y un punto (para el caso de viñetas enumeradas), por ejemplo: <br>
# `- Elemento con una viñeta guión seguido de un espacio (- ) ` <br>
# - Elemento con una viñeta guión seguido de un espacio (`- `) <br>
#
# `* Elemento con una viñeta asterisco (* ) seguido de un espacio` <br>
# * Elemento con una viñeta asterisco (`* `) seguido de un espacio <br>
#
# `1. Elemento con un número y punto (1. ) seguido de un espacio` <br>
# 1. Elemento con un número y punto (1. ) seguido de un espacio

# %% [markdown]
# En HTML las listas se crean con las etiquetas `<ul>` (no ordenadas) y `<ol>` (ordenadas). Cada elemento de la lista debe empezar con la etiqueta `<li>`. Ejemplo:

# %% [markdown]
# `<ul>`<br>
#     `<li>Café</li>`<br>
#     `<li>Leche</li>`<br>
#     `<li>Té</li>`<br>
# `</ul>`<br>
#
#
# <ul>
#     <li>Café</li>
#     <li>Leche</li>
#     <li>Té</li>
# </ul>

# %% [markdown]
# `<ol>`<br>
#     `<li>Café</li>`<br>
#     `<li>Leche</li>`<br>
#     `<li>Té</li>`<br>
# `</ol>`<br>
#
#
# <ol>
#     <li>Café</li>
#     <li>Leche</li>
#     <li>Té</li>
# </ol>

# %% [markdown]
# ## 1.7. Crear tablas

# %% [markdown]
# Para crear tablas en HTML empleamos las etiquetas de apertura y cierre `<table></table>`. Cada fila y su contenido deben registrarse con las etiquetas `<tr></tr>` y `<td></td>`. Ejemplo:

# %% [markdown]
# `<table>` <br>
#   `<tr>`<br>
#     `<th>Compañia</th>`<br>
#     `<th>Contacto</th>`<br>
#     `<th>País</th>`<br>
#   `</tr>`<br>
#   `<tr>`<br>
#     `<td>Alfreds Futterkiste</td>`<br>
#     `<td>Maria Anders</td>`<br>
#     `<td>Alemanía</td>`<br>
#   `</tr>`<br>
#   `<tr>`<br>
#     `<td>Centro comercial Moctezuma</td>`<br>
#     `<td>Francisco Chang</td>`<br>
#     `<td>México</td>`<br>
#   `</tr>`<br>
# `</table>`<br>

# %% [markdown]
# <table>
#   <tr>
#     <th>Compañia</th>
#     <th>Contacto</th>
#     <th>País</th>
#   </tr>
#   <tr>
#     <td>Alfreds Futterkiste</td>
#     <td>Maria Anders</td>
#     <td>Alemanía</td>
#   </tr>
#   <tr>
#     <td>Centro comercial Moctezuma</td>
#     <td>Francisco Chang</td>
#     <td>México</td>
#   </tr>
# </table>

# %% [markdown]
# ## 1.8. Subir imágenes

# %% [markdown]
# Para subir imágenes empleamos la etiqueta `<img>`. Ejemplo:

# %% [markdown]
# `<img src="Earth.png" alt="Tierra">`

# %% [markdown]
# <img src="Earth.png" alt="Tierra">

# %% [markdown]
# # <u>2. Manual de "MathJax" para la notación matemática en textos científicos </u> <br>
#
# <a href="https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference">Guía básica de MathJax</a>

# %% [markdown]
# <a href="https://www.overleaf.com/learn/latex/Integrals%2C_sums_and_limits"> Curso de LaTex </a>

# %% [markdown]
# Las expresiones matemáticas en Markdown están basadas en <a href="https://es.wikipedia.org/wiki/LaTeX">LaTeX</a>, Para mostrar una ecuación en línea con el texto, puede usar un solo signo de dólar `$` antes y después de la ecuación. Por ejemplo, `$E = m*c^{2} $` ($E = m*c^{2} $).

# %% [markdown]
# Para mostrar una ecuación como bloque, se usan dos signos de dólar `$$` antes y después de la ecuación. Por ejemplo:

# %% [markdown]
# `$$`
# `\begin{aligned}`
# `f(x) &= x^2 \\`
# `f'(x) &= 2x \\`
# `F(x) &= \int f(x)\\`
# `&= \frac{x^3}{3} \\`
# `\end{aligned}`
# `$$`

# %% [markdown]
# $$
# \begin{aligned}
# f(x) &= x^2 \\
# f'(x) &= 2x \\
# F(x) &= \int f(x)\\
# &= \frac{x^3}{3} \\
# \end{aligned}
# \tag{1}
# $$

# %% [markdown]
# Los comandos para algunas expresiones matemáticas son los siguientes:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# En estas las siguientes líneas se observan algunos ejemplos:

# %% [markdown]
# $
# \begin{vmatrix}
# 1 & 2 & 3 & 4\\
# a & b & c & y\\
# a & b & c & y
# \end{vmatrix}
# $

# %% [markdown]
# $ A=
# \begin{vmatrix}
# 1 & 2 & 3 & 4\\
# a & b & c & y\\
# a & b & c & y
# \end{vmatrix}
# $

# %% [markdown]
# $
# \iiiint_V \mu(t,u,v,w) \,dt\,du\,dv\,dw
# $

# %% [markdown]
# $ \sum_{i}^{n} {\frac{1}{4i}} $
#
# $ \sum_{i}^{n} \left(\frac {1}{4i} \right) $

# %% [markdown]
#  <h1 style="color red;"> <u>3. Magnitudes y sistemas de unidades </u> </font>

# %% [markdown]
# <h2>3.1. Magnitud</h2>
#
# Las magnitudes son propiedades que pueden medirse mediante un valor numérico y una unidad. En el siglo XVIII, la academía francesa de ciencias recomienda la implantación de estándares invariables para todas las medidas y pesos. Esto dio como resultado al sistema internacional de unidades (SIU).<br>
#
# Aunque el SIU es el más extendido en el mundo, no es el único sistema de medidas. Otros sistemas que se destacan son: el cegesimal, el cual emplea la longitud, masa y tiempo como unidades fundamentales; el sistema técnico, el cual emplea la fuerza como magnitud fundamental y la masa como su magnitud derivada; y el sistema británico.

# %% [markdown]
# ## 3.2. Análisis dimensional:
# <p>El análisis dimensional es una de las herramientas más valiosas que utilizan los científicos y los ingenieros. Permite la conversión entre una cantidad en una unidad a la cantidad correspondiente en una unidad deseada usando varios factores de conversión. </p> <br>
#
# <p><b> Simbología para el análisis dimensional en unidades primarias:</b></p> <br>
# <p>Masa: [M]</p> <br>
# <p>Longitud: [L]</p> <br>
# <p>Tiempo: [T]</p> <br>
# <p>Temperatura: [$\theta$]</p> <br>

# %% [markdown]
# <p>Miremos unos ejemplos:</p> <br>
#
# <p> <b> 1. Ecuación de la energía cinética: </b></p>
# $$E_{cinética} = {\frac 1 2} m {\vec V^{2}} $$

# %% [markdown]
# $\require{cancel}$ <!-- Librería para visualizar la cancelación de unidades -->
# $E_{cinética} = {\frac 1 2} [M] {\frac {[L]^2}{[T]^2}} $ <br>
# $E_{cinética} = {\frac 1 2} [M] {\frac {[L]}{[T]^2}} [L] $ <br>
# <p>La unidad de la energía cinética en el S.I. es el Joule (J)</p> <br>
#
# <p>De acuerdo al análisis dimensional 1 J tiene unidades de: </p> <br>
#
# <p> Masa, longitud y tiempo, que las podriamos representar en términos de velocidad y aceleración segun el caso: </p> <br>
#
# $E_{cinética} = {\frac 1 2} [Masa] {[\vec {velocidad}]^2} $ <br>
# $E_{cinética} = {\frac 1 2} [kg] {[\frac {m}{s}]^2} $ <br>
# $E_{cinética} = {\frac 1 2} [Masa] {[aceleración] * [distancia]} $ <br>
# $E_{cinética} = {\frac 1 2} [kg] {\left[\frac {m}{s^2} \right] * [m]} $ <br>
# $1 J = 1 kg {\frac {m^2}{s^2}}$

# %% [markdown]
# <b> 2. Imagine que un químico quiere medir 0.214 ml de benceno, pero carece del equipo para medir con precisión un volumen tan pequeño. El químico, sin embargo, está equipado con una balanza analítica capaz de medir $\pm 0.0001g$. Mirando en una tabla de referencia, el químico aprende la densidad del benceno $(\rho=0.8765g/mL)$. ¿Cuántos gramos de benceno debe usar el químico?</b> <br>

# %% [markdown]
# <p>Gramos de benceno a usar: </p> <br>
# $gramos_{benceno} = Volumen *  densidad$ <br>
# $g_{b} = 0.214 \cancel{ml} * 0.8765 {\frac {g}{\cancel{ml}}}$ <br>
# $g_{b} = 0.187571 g$ <br>
# <p> Observe que los ml se dividieron por ml, una unidad equivalente. </p> <br>
# <p>Ya que este resultado tiene demasiadas cifras significativas y debe redondearse a tres dígitos significativos (esto se debe a que 0.214 mL tiene tres dígitos significativos y el factor de conversión tenía cuatro dígitos significativos.).</p> <br>
#
# <p>$g_{b} = 0.188 g$</p>

# %% [markdown]
# ## **EJEMPLOS DE CONVERSIÓN DE UNIDADES**

# %% [markdown]
# <p>Para este caso creareamos funciones en <b>Python</b> para realizar conversiones de unidades del Sistema Internacional (SI) al Sistema Inglés o viceversa.</p>

# %% [markdown]
# <p>Unidades básicas del SI:</p>
# $
# \begin{array}{|c|c|c|}
# \hline
#   \text{Simbolo} & \text{Nombre} & \text{Magnitud} \\
# \hline
#    s & Segundo & Tiempo \\
# \hline
#    m & Metro & Longitud \\
# \hline
#    kg & Kilogramo & Masa \\
# \hline
#    A & Amperio & Corriente \hspace{2mm} eléctrica \\
# \hline
#    mol & Mol & Cantidad \hspace{2mm} de \hspace{2mm} sustancia \\
# \hline
#    cd & Candela & Intensidad \hspace{2mm} luminosa \\
# \hline
#    K & Kelvin & Temperatura \hspace{2mm} luminosa \\
# \hline
# \end{array}
# $

# %% [markdown]
# <p><b>Nota: </b> la sintaxis para crear funciones en <b>Python</b> la pueden consultar en el siguiente enlace <a href="https://www.w3schools.com/python/python_functions.asp"> "Funciones en Python"</a>. </p>

# %% [markdown]
# ### **Ejemplo 1:**
#
# <p>Algunas unidades de longitud empleadas en el sistema alglosajón son el pie (ft), la milla (ml) y la pulgada (in), cuyo equivalente a metros es de: </p> <br>
# 1.) 1 ft = 0.3048 m <br>
# 2.) 1 mi = 1609.344 m <br>
# 3.) 1 in = 0.0254 m <br>
#
# <p>De acuerdo con la información mostrada, cree una función que permita pasar de metros a pies (millas y pulgadas) y de pies (millas y pulgadas) a metros.</p>

# %% [markdown]
# $1\cancel{m} * {\frac {1 ft}{0.3048 \cancel{m}}} = 3.2808 ft$ <br>
# $1 \cancel{m} * {\frac {1 mi}{1609.344 \cancel{m}}} = 6.214*10^{-4} mi$ <br>
# $1 \cancel{m} * {\frac {1 in}{0.0254 \cancel{m}}} = 39.370 in$ <br>
# <hr>
# $1 \cancel{ft} * {\frac {0.3048 m}{1 \cancel{ft}}} = 0.3048 m$ <br>
# $1 \cancel{ft} * {\frac {12 in}{1 \cancel{ft}}} = 12 in$ <br>
# $1 \cancel{ft} * {\frac {0.00018939 mi}{1 \cancel{ft}}} = 1.8939*10^{-4} mi$ <br>
# <hr>
# $1 \cancel{in} * {\frac {0.0254 m}{1 \cancel{in}}} = 2.54*10^{-2} m$ <br>
# $1 \cancel{in} * {\frac {1 ft}{12 \cancel{in}}} = 8.33*10^{-2} ft$ <br>
# $1 \cancel{in} * {\frac {0.0000157828 mi}{1 \cancel{in}}} = 1.57828*10^{-5} mi$ <br>
# <hr>
# $1 \cancel{mi} * {\frac {1609.344 m}{1 \cancel{mi}}} = 1609.344 m$ <br>
# $1 \cancel{mi} * {\frac {1 ft}{0.00018939 \cancel{mi}}} = 5280.110 ft$ <br>
# $1 \cancel{mi} * {\frac {1 in}{0.0000157828 \cancel{mi}}} = 63360.114 in$ <br>

# %%
# Transformar unidades de longitud
# Definir función
# Para este caso llamaremos a nuestra función ConvLong

def ConvLong(und1,und2, valor): #Esta función convierte el valor dado de la unidad 1 (und1) a la unidad 2 (und 2).
    if und1=="m" and und2=="ft":
        Respuesta = valor/0.3048
    elif und1=="m" and und2=="mi":
        Respuesta = valor/1609.344
    elif und1=="m" and und2=="in":
        Respuesta = valor/0.0254
    elif und1=="ft" and und2=="m":
        Respuesta = valor * 0.348
    elif und1=="ft" and und2=="in":
        Respuesta = valor * 12
    elif und1=="ft" and und2=="mi":
        Respuesta = valor * 0.00018939
    elif und1=="in" and und2=="m":
        Respuesta = valor * 0.0254
    elif und1=="in" and und2=="ft":
        Respuesta = valor/12
    elif und1=="in" and und2=="mi":
        Respuesta = valor*0.0000157828
    elif und1=="mi" and und2=="m":
        Respuesta = valor*1609.344
    elif und1=="mi" and und2=="ft":
        Respuesta = valor*5280.100
    elif und1=="mi" and und2=="in":
        Respuesta = valor*63360.114

    print(valor, " ", und1, " equivalen a ", Respuesta, " ", und2)

# siglas que le daremos a las unidades metros (m), pies (ft), pulgadas (in), millas (mi)

# %%
# vamos a probar nuestra función convirtiendo 57 metros a pulgadas

ConvLong("m","ft",1)
# Out:
# 1   m  equivalen a  3.280839895013123   ft

# %%
# vamos a convertir 8 millas a metros

ConvLong("mi","m",8)
# Out:
# 8   mi  equivalen a  12874.752   m

# %% [markdown]
# ### **Ejemplo 2:**
# <p>Crear una función que permitas transformar unidades de calor como Joules, Btu y calorías.</p>

# %% [markdown]
# $1 J = 1kg *{\frac {m^2}{s^2}} = 1 N*m = 1 Pa*m^{3} = 1 W*s = 9.478 * 10^{-4} Btu = 2.389 *10^{-4} kcal $ <br>
# $1 N = 1kg *{\frac {m}{s^2}} = {\frac {Pa}{m^2}}$ <br>

# %%
def ConvEner(und1,und2, valor):
    if und1=="J" and und2=="Btu":
        Respuesta = valor*(9.478/10000)
    elif und1=="J" and und2=="cal":
        Respuesta = valor*(2.389/10)
    elif und1=="Btu" and und2=="J":
        Respuesta = valor*(10000/9.478)
    elif und1=="Btu" and und2=="cal":
        Respuesta = valor*((1000*2.389)/9.478)
    elif und1=="cal" and und2=="J":
        Respuesta = valor*(10/2.389)
    elif und1=="cal" and und2=="Btu":
        Respuesta = valor*(9.478/(2.389*1000))
    print(valor, " ", und1, " equivalen a ", Respuesta, " ", und2)

# siglas que le daremos a las unidades Joules (J), calorías (ca), British thermal units (Btu)

# %%
# Convertir 100 calorías a Joules

ConvEner("cal","J",100)
# Out:
# 100   cal  equivalen a  418.5851820845542   J

# %%
# Convertir 100 J a Btu

ConvEner("J","Btu",100)
# Out:
# 100   J  equivalen a  0.09477999999999999   Btu

# %% [markdown]
# ## **EJERCICIOS**
#
# <p>1. Crear una función que permita la conversión de las siguientes unidades concentración: molaridad (M), normalidad (N), peso-volumen (pv) y partes por millón (ppm). Emplee las variables que considere necesarias para desarrollar su función.</p>
#
# <p>2. Crear una función que permita la conversión de al menos tres unidades de presión.</p>
